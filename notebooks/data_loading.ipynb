# %% [markdown]
# # Data Loading for Absolute Pose Estimation

# %%
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append('..')
import os
import numpy as np
from PIL import Image
import torch
import torch.utils.data as data
from torchvision import transforms

# %% [markdown]
# ## Load Datasets

# %%
from utils.datasets.preprocess import get_transform_ops
from utils.datasets.abspose import AbsPoseDataset

# Load all scenes of one dataset
data_root = '../data/CambridgeLandmarks'
dataset = 'ShopFacade'
dataset_txt = 'dataset_test.txt'
ops = get_transform_ops(resize=256, crop='random')
data_src = AbsPoseDataset(dataset, data_root, dataset_txt, ops)

# %% [markdown]
# ## Visualize dataset samples

# %%
from utils.notebook.plotting import plot_im_loader

data_loader = data.DataLoader(data_src, batch_size=8, shuffle=True, num_workers=0)
plot_im_loader(data_loader, row_max=1)
